# %%
import psycopg2
import pandas as pd

conexao = psycopg2.connect(host='bmazega-bmazega.d.aivencloud.com',
  user ='avnadmin',
  password = '################',
  port = '18437',
  database = 'academia')

# %% [markdown]
# # TRABALHO 01:  Sistema de Gerenciamento de Franquias
# Trabalho desenvolvido durante a disciplina de BD1
#
# ## Sumário
#
# ## 1. COMPONENTES<br>
# Integrantes do grupo<br>
# Brayan Mazega de Freitas Souza - brayanmazega@gmail.com<br>
# Irene Schmidt da Silva Alves -  irenealvesbsi@gmail.com<br>
# Irlane Schmidt da Silva Alves -  irlanesilvabsi@gmail.com<br>
# Rafael Calazans de Jesus - raf4cj12@gmail.com <br>
#
#
# ## 2.MINI-MUNDO<br>
#
# > O sistema proposto para uma rede de academias conterá as informações aqui detalhadas. De uma franquia, serão armazenados o código da franquia, a localização, o horário de abertura e o horário de fechamento. É válido ressaltar que a rede de academias possui alunos e professores, que, por sua vez, são pessoas. De uma pessoa, deseja-se saber o código, o nome, o CPF e a data de nascimento. De um aluno, deseja-se saber também a altura e o peso. Já de um professor, deseja-se saber a especialidade. Um professor pode trabalhar em uma ou mais franquias e pode auxiliar em uma ou mais atividades, sendo necessário saber a data e o horário de início e de fim do trabalho. De uma atividade, é desejável saber o código e o nome. Um aluno assina um e somente um plano. De um plano, deve-se saber o código, o nome, o período de duração do plano e o valor mensal. Uma atividade pode ser oferecida em nenhuma ou mais de uma franquia. Um aluno pode frequentar nenhuma ou mais franquias, desejando-se saber a data e o horário de entrada e de saída.
#
# ## 3.PERGUNTAS A SEREM RESPONDIDAS<br>
# ### 3.1 QUAIS PERGUNTAS PODEM SER RESPONDIDAS COM O SISTEMA PROPOSTO?
#     a) O sistema proposto poderá fornecer quais tipos de relatórios e informaçes?
#     b) Crie uma lista com os 5 principais relatórios que poderão ser obtidos por meio do sistema proposto!
#
# > A academia precisa inicialmente dos seguintes relatórios:
#
# > Relatório de Alunos por Plano: Detalhando o nome, CPF, peso, data de nascimento, altura e o plano assinado por cada aluno.
#
# > Relatório de Professores por Especialidade: Listando o nome, CPF, data de nascimento e especialidade de cada professor, incluindo as franquias em que trabalham.
#
# > Relatório de Utilização das Academias: Informando a localização das academias, horários de abertura e fechamento, quantidade de alunos e as franquias associadas.
#
# > Relatório Financeiro dos Planos: Incluindo nome, valor e período de cada plano, com análise de receitas geradas.
#
# > Relatório de Atividades: Detalhando o nome da atividade, o professor responsável e as franquias onde são oferecidas.
#
#
#
# ## 5.MODELO CONCEITUAL<br>
#     A) Utilizar a Notação adequada (Preferencialmente utilizar o BR Modelo 3)
#     B) O mínimo de entidades do modelo conceitual pare este trabalho será igual a 3 e o Máximo 5.
#         * informe quais são as 3 principais entidades do sistema em densenvolvimento<br>(se houverem mais de 3 entidades, pense na importância da entidade para o sistema)
#     C) Principais fluxos de informação/entidades do sistema (mínimo 3). <br>Dica: normalmente estes fluxos estão associados as tabelas que conterão maior quantidade de dados
#     D) Qualidade e Clareza
#         Garantir que a semântica dos atributos seja clara no esquema (nomes coerentes com os dados).
#         Criar o esquema de forma a garantir a redução de informação redundante, possibilidade de valores null,
#         e tuplas falsas (Aplicar os conceitos de normalização abordados).
#
# ![Modelo conceitual](https://github.com/user-attachments/assets/cb547b1d-fe63-49eb-8c9e-03e7345d3730)
#
#
# ### 5.1 Validação do Modelo Conceitual
#     [Grupo01]: Caio lessa, Marcos Vinicius, Thiago Borges e Davidson Santos
#     [Grupo02]: [Ana Júlia Martins, Jessica Nogueira Duque, Larissa Rangel,Matheus Caldas]
#
# ### 5.2 Descrição dos dados
#
#
# PESSOA: Tabela que armazena as informações relativas aos professores e alunos.
#
#     [NOME]: [Campo que armazena o nome completo.]
#
#     [CPF]: [Campo que armazena o número de Cadastro de Pessoa Física].
#
#     [DATA DE NASCIMENTO]: [Campo que armazena a data de nascimento.]
#
#
# ALUNO: Tabela que armazena as informações relativas aos alunos.
#
#     [PESO]: [Campo que armazena o peso do aluno.]
#     [ALTURA]: [Campo que armazena a altura do aluno.]
#
# PROFESSOR: Tabela que armazena as informações relativas aos professores.<br>
#
#
#     [ESPECIALIDADE]: [Campo que armazena a especialidade do professor.]
#
# FRANQUIA: Tabela que armazena as informações relativas às academias.<br>
#
#     LOCALIZAÇÃO: Campo que armazena a localização da academia.<br>
#     HORÁRIO DE ABERTURA: Campo que armazena o horário de abertura da academia.
#     HORÁRIO DE FECHAMENTO: Campo que armazena o horário de fechamento da academia.
#
# PLANO: Tabela que armazena as informações relativas aos planos oferecidos.<br>
#
#     [NOME]: [Campo que armazena o nome do plano.]
#     [PERÍODO]: [Campo que armazena o período de duração do plano.]
#
# ATIVIDADE: Tabela que armazena as informações relativas às atividades oferecidas.<br>
#
#     [NOME]: [Campo que armazena o nome da atividade.]
#
#
# ># Marco de Entrega 01: Do item 1 até o item 5.2 (5 PTS) <br>
#
# ## 6	MODELO LÓGICO<br>
#         a) inclusão do esquema lógico do banco de dados
#         b) verificação de correspondencia com o modelo conceitual
#         (não serão aceitos modelos que não estejam em conformidade)
#
#  ![image](https://github.com/user-attachments/assets/45f4b03f-a2d1-4e31-9a9b-b692a77cf74d)
#
#  ## 7	MODELO FÍSICO<br>
#         a) inclusão das instruções de criacão das estruturas em SQL/DDL
#         (criação de tabelas, alterações, etc..)
#
#  Link do arquivo SQL: https://drive.google.com/file/d/1S4HYxToX4RqePdT1QIH37pUuOmP0g7R6/view?usp=drive_link
#
#  ## 8	INSERT APLICADO NAS TABELAS DO BANCO DE DADOS<br>
#         a) Script das instruções relativas a inclusão de dados
# 	Requisito mínimo: (Script dev conter: Drop para exclusão de tabelas + create definição de para tabelas e estruturas de dados + insert para dados a serem inseridos)
#         OBS
# 	1) Criar um novo banco de dados para testar a restauracao (em caso de falha na restauração o grupo não pontuará neste quesito)
#         2) script deve ser incluso no template em um arquivo no formato .SQL
#
# Link do arquivo SQL: https://docs.google.com/document/d/1XLt5WeQaOmhdbiqnxXr0Ut4ipEypsJQn7onz3ZgwAZA/edit?usp=sharing
#
# ## 9	TABELAS E PRINCIPAIS CONSULTAS<br>
#     OBS: Usa template da disciplina disponibilizado no Colab.<br>
# ### 9.1	CONSULTAS DAS TABELAS COM TODOS OS DADOS INSERIDOS (Todas) <br>

# %%
pessoa = pd.read_sql_query ('SELECT * from pessoa', conexao)
pessoa
# Out:
# <ipython-input-55-f86ba90e0ebe>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pessoa = pd.read_sql_query ('SELECT * from pessoa', conexao)
#      codigo                nome             cpf data_nascimento
# 0         1          João Silva  123.456.789-00      1990-05-15
# 1         2        Maria Santos  987.654.321-00      1985-07-20
# 2         3         Pedro Souza  456.789.123-00      1998-02-10
# 3         4        Ana Oliveira  321.654.987-00      1977-11-25
# 4         5        José Pereira  789.123.456-00      2000-09-05
# ..      ...                 ...             ...             ...
# 115     116  Daniela Figueiredo  730.400.500-81      1994-09-25
# 116     117     Emanuel Pereira  740.500.600-82      1996-10-30
# 117     118        Flávia Souza  750.600.700-83      1999-11-05
# ...

# %%
aluno = pd.read_sql_query ('SELECT * from aluno', conexao)
aluno
# Out:
# <ipython-input-56-2522b53e4d80>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   aluno = pd.read_sql_query ('SELECT * from aluno', conexao)
#     altura  peso  fk_pessoa_codigo
# 0     1.75  70.5                 1
# 1     1.68  65.0                 2
# 2     1.80  80.2                 3
# 3     1.65  60.0                 8
# 4     1.72  68.0                 9
# ..     ...   ...               ...
# 95    1.78  78.0               116
# 96    1.67  67.0               117
# 97    1.69  69.0               118
# 98    1.71  71.0               119
# 99    1.73  73.0               120
#
# [100 rows x 3 columns]

# %%
professor = pd.read_sql_query ('SELECT * from professor', conexao)
professor
# Out:
# <ipython-input-2-afc9db2552e7>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   professor = pd.read_sql_query ('SELECT * from professor', conexao)
#        especialidade  fk_pessoa_codigo
# 0    Educação Física                 4
# 1           Nutrição                 5
# 2         Musculação                 6
# 3          Fit dance                 7
# 4               Yoga                12
# 5            Pilates                13
# 6           Crossfit                14
# 7   Personal Trainer                15
# 8          Muay Thai                24
# 9               Boxe                25
# 10          Spinning                26
# 11       Alongamento                27
# 12         Funcional                28
# 13       Bike Indoor                29
# 14              Judo                30
# ...

# %%
franquia = pd.read_sql_query ('SELECT * from franquia', conexao)
franquia
# Out:
# <ipython-input-3-a03f6f1ae59d>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   franquia = pd.read_sql_query ('SELECT * from franquia', conexao)
#     codigo                               localizacao hora_abertura  \
# 0        1                Laranjeiras, Jardim A, 123      05:00:00
# 1        2         Jardim Camburi,  Praça Verde, 456      06:30:00
# 2        3  Praia do Canto, Praia das Estrelas, 1252      07:30:00
# 3        4          Cariacica, Jardim das Rosas, 520      08:00:00
# 4        5           Eurico Salles, Santa Clara, 351      07:00:00
# 5        6                Centro, Rua Principal, 123      06:00:00
# 6        7        Campo Grande, Avenida Central, 456      06:30:00
# 7        8           Vila Velha, Rua das Flores, 789      07:00:00
# 8        9                 Serra, Avenida Norte, 101      05:30:00
# ...

# %%
plano = pd.read_sql_query ('SELECT * from plano', conexao)
plano
# Out:
# <ipython-input-59-ee604f38a22a>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   plano = pd.read_sql_query ('SELECT * from plano', conexao)
#    codigo      nome     periodo
# 0       1    bronze      mensal
# 1       2    silver  trimestral
# 2       3      gold   semestral
# 3       4  platinum       anual

# %%
atividade = pd.read_sql_query ('SELECT * from atividade', conexao)
atividade
# Out:
# <ipython-input-4-0394953e2915>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   atividade = pd.read_sql_query ('SELECT * from atividade', conexao)
#     codigo                  nome
# 0        1            Musculação
# 1        2                 Zumba
# 2        3              crossfit
# 3        4  Acompanhamento dieta
# 4        5                  Yoga
# 5        6               Pilates
# 6        7             Fit Dance
# 7        8             Muay Thai
# 8        9                  Boxe
# 9       10              Spinning
# 10      11           Alongamento
# 11      12             Funcional
# 12      13           Bike Indoor
# 13      14                  Judo
# 14      15        Defesa pessoal

# %%
aluno_plano = pd.read_sql_query ('SELECT * from aluno_plano', conexao)
aluno_plano
# Out:
# <ipython-input-81-f7c4d0be7b40>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   aluno_plano = pd.read_sql_query ('SELECT * from aluno_plano', conexao)
#     codigo  fk_plano_codigo  fk_aluno_fk_pessoa_codigo  valor        data
# 0        1                1                          1   80.0  2024-07-11
# 1        2                2                          2  300.0  2024-07-11
# 2        3                3                          3  500.0  2024-07-11
# 3        4                2                          8  300.0  2024-07-15
# 4        5                1                          9   80.0  2024-07-16
# ..     ...              ...                        ...    ...         ...
# 95      96                1                        116   80.0  2024-10-08
# 96      97                2                        117  300.0  2024-10-09
# ...

# %%
aluno_franquia = pd.read_sql_query ('SELECT * from aluno_franquia', conexao)
aluno_franquia
# Out:
# <ipython-input-47-9708272018cf>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   aluno_franquia = pd.read_sql_query ('SELECT * from aluno_franquia', conexao)
#      fk_franquia_codigo  fk_aluno_fk_pessoa_codigo    data_hora_inicio  \
# 0                     1                          1 2024-08-01 10:00:00
# 1                     2                          2 2024-08-02 15:00:00
# 2                     3                          3 2024-08-03 17:00:00
# 3                     1                          1 2024-07-11 18:00:00
# 4                     2                          2 2024-05-10 14:00:00
# ..                  ...                        ...                 ...
# 123                  15                         46 2024-08-16 13:00:00
# 124                  15                         49 2024-08-17 14:00:00
# ...

# %%
professor_franquia = pd.read_sql_query ('SELECT * from professor_franquia', conexao)
professor_franquia
# Out:
# <ipython-input-6-35c756bd602f>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   professor_franquia = pd.read_sql_query ('SELECT * from professor_franquia', conexao)
#     fk_professor_fk_pessoa_codigo  fk_franquia_codigo    data_hora_inicio  \
# 0                               4                   2 2024-07-11 06:30:00
# 1                               5                   1 2024-05-10 14:00:00
# 2                               6                   1 2024-05-10 05:00:00
# 3                               7                   2 2024-07-11 14:30:00
# 4                              12                   3 2024-07-15 08:00:00
# ..                            ...                 ...                 ...
# 64                             31                  12 2024-07-23 06:30:00
# ...

# %%
professor_atividade = pd.read_sql_query ('SELECT * from professor_atividade', conexao)
professor_atividade
# Out:
# <ipython-input-7-53e65e69d2a0>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   professor_atividade = pd.read_sql_query ('SELECT * from professor_atividade', conexao)
#     fk_atividade_codigo  fk_professor_fk_pessoa_codigo
# 0                     1                              6
# 1                     2                              7
# 2                     3                              4
# 3                     4                              5
# 4                     5                             12
# ..                  ...                            ...
# 61                    9                             31
# 62                   10                             32
# 63                   11                             34
# 64                   12                             35
# ...

# %%
atividade_franquia = pd.read_sql_query ('SELECT * from atividade_franquia', conexao)
atividade_franquia
# Out:
# <ipython-input-7-6cc7d75a54cc>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   atividade_franquia = pd.read_sql_query ('SELECT * from atividade_franquia', conexao)
#     fk_atividade_codigo  fk_franquia_codigo
# 0                     1                   1
# 1                     2                   2
# 2                     3                   2
# 3                     4                   1
# 4                     7                   1
# ..                  ...                 ...
# 58                    1                   4
# 59                    2                   5
# 60                    3                   6
# 61                    4                   7
# 62                    5                   8
#
# [63 rows x 2 columns]

# %% [markdown]
# ### 9.2	CONSULTAS DAS TABELAS COM FILTROS WHERE (Mínimo 4)<br>

# %%
aluno_peso = pd.read_sql_query('SELECT * from aluno a Where a.peso > 70', conexao)
aluno_peso
# Out:
# <ipython-input-8-46b5c3368b65>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   aluno_peso = pd.read_sql_query('SELECT * from aluno a Where a.peso > 70', conexao)
#     altura  peso  fk_pessoa_codigo
# 0     1.75  70.5                 1
# 1     1.80  80.2                 3
# 2     1.90  85.0                10
# 3     1.78  75.5                11
# 4     1.82  82.0                16
# ..     ...   ...               ...
# 58    1.72  72.0               113
# 59    1.74  74.0               115
# 60    1.78  78.0               116
# 61    1.71  71.0               119
# 62    1.73  73.0               120
#
# [63 rows x 3 columns]

# %%
aluno_altura = pd.read_sql_query('SELECT * from aluno a Where a.altura < 1.80', conexao)
aluno_altura
# Out:
# <ipython-input-9-b1f048e21d55>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   aluno_altura = pd.read_sql_query('SELECT * from aluno a Where a.altura < 1.80', conexao)
#     altura  peso  fk_pessoa_codigo
# 0     1.75  70.5                 1
# 1     1.68  65.0                 2
# 2     1.65  60.0                 8
# 3     1.72  68.0                 9
# 4     1.78  75.5                11
# ..     ...   ...               ...
# 90    1.78  78.0               116
# 91    1.67  67.0               117
# 92    1.69  69.0               118
# 93    1.71  71.0               119
# 94    1.73  73.0               120
#
# [95 rows x 3 columns]

# %%
plano_aluno = pd.read_sql_query('SELECT * from aluno_plano a Where a.valor > 300', conexao)
plano_aluno
# Out:
# <ipython-input-10-f3a057a240ad>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   plano_aluno = pd.read_sql_query('SELECT * from aluno_plano a Where a.valor > 300', conexao)
#     codigo  fk_plano_codigo  fk_aluno_fk_pessoa_codigo  valor        data
# 0        3                3                          3  500.0  2024-07-11
# 1        6                3                         10  500.0  2024-07-16
# 2        8                3                         18  500.0  2024-02-17
# 3       10                4                         20  900.0  2024-09-12
# 4       18                3                         38  500.0  2024-07-22
# 5       19                4                         39  900.0  2024-07-23
# 6       22                3                         42  500.0  2024-07-26
# ...

# %%
aula_professor = pd.read_sql_query('SELECT * from professor_franquia p Where p.fk_franquia_codigo = 1', conexao)
aula_professor
# Out:
# <ipython-input-11-9d5cc9328a07>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   aula_professor = pd.read_sql_query('SELECT * from professor_franquia p Where p.fk_franquia_codigo = 1', conexao)
#    fk_professor_fk_pessoa_codigo  fk_franquia_codigo    data_hora_inicio  \
# 0                              5                   1 2024-05-10 14:00:00
# 1                              6                   1 2024-05-10 05:00:00
# 2                             28                   1 2024-07-12 05:00:00
# 3                              5                   1 2024-05-10 14:00:00
# 4                              6                   1 2024-05-10 05:00:00
# 5                             35                   1 2024-07-16 11:00:00
#
#         data_hora_fim
# 0 2024-05-10 22:00:00
# 1 2024-05-10 14:00:00
# 2 2024-07-12 14:00:00
# ...

# %% [markdown]
# ### 9.3	CONSULTAS QUE USAM OPERADORES LÓGICOS, ARITMÉTICOS E TABELAS OU CAMPOS RENOMEADOS (Mínimo 11)
#     a) Criar 5 consultas que envolvam os operadores lógicos AND, OR e Not
#     b) Criar no mínimo 3 consultas com operadores aritméticos
#     c) Criar no mínimo 3 consultas com operação de renomear nomes de campos ou tabelas

# %% [markdown]
# a) Criar 5 consultas que envolvam os operadores lógicos AND, OR e Not

# %%
filtro_aluno_altura = pd.read_sql_query('SELECT * from aluno a where a.altura > 1.68 AND a.altura < 1.92', conexao)
filtro_aluno_altura
# Out:
# <ipython-input-12-57cac62fb6bb>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   filtro_aluno_altura = pd.read_sql_query('SELECT * from aluno a where a.altura > 1.68 AND a.altura < 1.92', conexao)
#     altura  peso  fk_pessoa_codigo
# 0     1.75  70.5                 1
# 1     1.80  80.2                 3
# 2     1.72  68.0                 9
# 3     1.90  85.0                10
# 4     1.78  75.5                11
# ..     ...   ...               ...
# 68    1.74  74.0               115
# 69    1.78  78.0               116
# 70    1.69  69.0               118
# 71    1.71  71.0               119
# 72    1.73  73.0               120
#
# [73 rows x 3 columns]

# %%
filtro_aluno_peso = pd.read_sql_query('SELECT * from aluno a where a.peso < 70 OR a.peso > 80', conexao)
filtro_aluno_peso
# Out:
# <ipython-input-13-22247ff7c447>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   filtro_aluno_peso = pd.read_sql_query('SELECT * from aluno a where a.peso < 70 OR a.peso > 80', conexao)
#     altura  peso  fk_pessoa_codigo
# 0     1.68  65.0                 2
# 1     1.80  80.2                 3
# 2     1.65  60.0                 8
# 3     1.72  68.0                 9
# 4     1.90  85.0                10
# 5     1.82  82.0                16
# 6     1.60  58.0                17
# 7     1.68  65.0                19
# 8     1.85  88.0                21
# 9     1.66  64.0                22
# 10    1.65  60.0                37
# 11    1.68  68.0                40
# 12    1.66  66.0                42
# 13    1.67  67.0                45
# 14    1.69  69.0                46
# 15    1.68  68.0                52
# ...

# %%
filtro_atividade_academia = pd.read_sql_query('SELECT * FROM atividade_franquia f where f.fk_atividade_codigo = 1 OR f.fk_atividade_codigo = 4', conexao)
filtro_atividade_academia
# Out:
# <ipython-input-14-cbf4955784ca>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   filtro_atividade_academia = pd.read_sql_query('SELECT * FROM atividade_franquia f where f.fk_atividade_codigo = 1 OR f.fk_atividade_codigo = 4', conexao)
#    fk_atividade_codigo  fk_franquia_codigo
# 0                    1                   1
# 1                    4                   1
# 2                    1                   1
# 3                    4                   4
# 4                    1                   2
# 5                    4                   5
# 6                    1                   3
# 7                    4                   6
# 8                    1                   4
# 9                    4                   7

# %%
filtro_academia_hora = pd.read_sql_query("SELECT * FROM franquia f where f.hora_abertura < '06:00:00' or f.hora_fechamento > '22:00:00'", conexao)
filtro_academia_hora
# Out:
# <ipython-input-15-3793637a7d21>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   filtro_academia_hora = pd.read_sql_query("SELECT * FROM franquia f where f.hora_abertura < '06:00:00' or f.hora_fechamento > '22:00:00'", conexao)
#    codigo                            localizacao hora_abertura hora_fechamento
# 0       1             Laranjeiras, Jardim A, 123      05:00:00        22:00:00
# 1       2      Jardim Camburi,  Praça Verde, 456      06:30:00        23:30:00
# 2       4       Cariacica, Jardim das Rosas, 520      08:00:00        23:00:00
# 3       7     Campo Grande, Avenida Central, 456      06:30:00        23:00:00
# 4       8        Vila Velha, Rua das Flores, 789      07:00:00        22:30:00
# 5       9              Serra, Avenida Norte, 101      05:30:00        21:30:00
# ...

# %%
filtro_aluno_plano = pd.read_sql_query("SELECT ap.*, p.nome from aluno_plano as ap inner join pessoa as p on p.codigo = ap.fk_aluno_fk_pessoa_codigo where ap.fk_plano_codigo not in (select codigo from plano where nome = 'platinum')", conexao)
filtro_aluno_plano
# Out:
# <ipython-input-16-dcc48bf9f018>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   filtro_aluno_plano = pd.read_sql_query("SELECT ap.*, p.nome from aluno_plano as ap inner join pessoa as p on p.codigo = ap.fk_aluno_fk_pessoa_codigo where ap.fk_plano_codigo not in (select codigo from plano where nome = 'platinum')", conexao)
#     codigo  fk_plano_codigo  fk_aluno_fk_pessoa_codigo  valor        data  \
# 0        1                1                          1   80.0  2024-07-11
# 1        2                2                          2  300.0  2024-07-11
# 2        3                3                          3  500.0  2024-07-11
# 3        4                2                          8  300.0  2024-07-15
# 4        5                1                          9   80.0  2024-07-16
# ...

# %% [markdown]
# b) Criar no mínimo 3 consultas com operadores aritméticos

# %%
aluno_imc = pd.read_sql_query('SELECT  p.nome, a.altura, a.peso,  ROUND(a.peso / (a.altura * a.altura)) as imc FROM aluno a JOIN pessoa p ON a.fk_pessoa_codigo = p.codigo', conexao)
aluno_imc
# Out:
# <ipython-input-17-52ca104f2162>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   aluno_imc = pd.read_sql_query('SELECT  p.nome, a.altura, a.peso,  ROUND(a.peso / (a.altura * a.altura)) as imc FROM aluno a JOIN pessoa p ON a.fk_pessoa_codigo = p.codigo', conexao)
#                   nome  altura  peso   imc
# 0           João Silva    1.75  70.5  23.0
# 1         Maria Santos    1.68  65.0  23.0
# 2          Pedro Souza    1.80  80.2  25.0
# 3          Carlos Lima    1.65  60.0  22.0
# 4          Clara Alves    1.72  68.0  23.0
# ..                 ...     ...   ...   ...
# 95  Daniela Figueiredo    1.78  78.0  25.0
# 96     Emanuel Pereira    1.67  67.0  24.0
# 97        Flávia Souza    1.69  69.0  24.0
# 98    Geraldo Nogueira    1.71  71.0  24.0
# 99       Hilda Cardoso    1.73  73.0  24.0
#
# [100 rows x 4 columns]

# %%
plano_bronze = pd.read_sql_query("SELECT pl.nome AS plano_nome, pl.periodo, SUM(ap.valor) AS valor_total,  COUNT(ap.fk_aluno_fk_pessoa_codigo) AS total_alunos, SUM(ap.valor) * COUNT(ap.fk_aluno_fk_pessoa_codigo) AS valor_total_alunos FROM  plano pl INNER JOIN  aluno_plano ap ON pl.codigo = ap.fk_plano_codigo WHERE pl.nome = 'bronze' GROUP BY pl.nome, pl.periodo", conexao)
plano_bronze
# Out:
# <ipython-input-18-48f34a2f7748>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   plano_bronze = pd.read_sql_query("SELECT pl.nome AS plano_nome, pl.periodo, SUM(ap.valor) AS valor_total,  COUNT(ap.fk_aluno_fk_pessoa_codigo) AS total_alunos, SUM(ap.valor) * COUNT(ap.fk_aluno_fk_pessoa_codigo) AS valor_total_alunos FROM  plano pl INNER JOIN  aluno_plano ap ON pl.codigo = ap.fk_plano_codigo WHERE pl.nome = 'bronze' GROUP BY pl.nome, pl.periodo", conexao)
#   plano_nome periodo  valor_total  total_alunos  valor_total_alunos
# 0     bronze  mensal       2080.0            26             54080.0

# %%
valor_total_alunos_planos = pd.read_sql_query(" SELECT  pl.nome AS plano_nome, pl.periodo, ap.valor AS valor,  COUNT(ap.fk_aluno_fk_pessoa_codigo) AS total_alunos, ap.valor * COUNT(ap.fk_aluno_fk_pessoa_codigo) AS valor_total_alunos FROM  plano pl INNER JOIN aluno_plano ap ON pl.codigo = ap.fk_plano_codigo GROUP BY pl.nome, pl.periodo, ap.valor", conexao)
valor_total_alunos_planos
# Out:
# <ipython-input-104-c06873e7981d>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   valor_total_alunos_planos = pd.read_sql_query(" SELECT  pl.nome AS plano_nome, pl.periodo, ap.valor AS valor,  COUNT(ap.fk_aluno_fk_pessoa_codigo) AS total_alunos, ap.valor * COUNT(ap.fk_aluno_fk_pessoa_codigo) AS valor_total_alunos FROM  plano pl INNER JOIN aluno_plano ap ON pl.codigo = ap.fk_plano_codigo GROUP BY pl.nome, pl.periodo, ap.valor", conexao)
#   plano_nome     periodo  valor  total_alunos  valor_total_alunos
# 0     silver  trimestral  300.0            25              7500.0
# 1       gold   semestral  500.0            24             12000.0
# 2     bronze      mensal   80.0            26              2080.0
# 3   platinum       anual  900.0            25             22500.0

# %% [markdown]
# c) Criar no mínimo 3 consultas com operação de renomear nomes de campos ou tabelas

# %%
aluno_plano = pd.read_sql_query("SELECT valor AS  valor_plano, p.nome as aluno FROM aluno_plano inner join pessoa p on aluno_plano.fk_aluno_fk_pessoa_codigo = p.codigo", conexao)
aluno_plano
# Out:
# <ipython-input-21-af57dd7c414c>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   aluno_plano = pd.read_sql_query("SELECT valor AS  valor_plano, p.nome as aluno FROM aluno_plano inner join pessoa p on aluno_plano.fk_aluno_fk_pessoa_codigo = p.codigo", conexao)
#     valor_plano               aluno
# 0          80.0          João Silva
# 1         300.0        Maria Santos
# 2         500.0         Pedro Souza
# 3         300.0         Carlos Lima
# 4          80.0         Clara Alves
# ..          ...                 ...
# 95         80.0  Daniela Figueiredo
# 96        300.0     Emanuel Pereira
# 97        500.0        Flávia Souza
# 98        900.0    Geraldo Nogueira
# 99         80.0       Hilda Cardoso
#
# [100 rows x 2 columns]

# %%
plano = pd.read_sql_query("SELECT codigo AS cod, nome AS  nome_plano, periodo AS  periodo_plano FROM plano", conexao)
plano
# Out:
# <ipython-input-19-d5a9296861f6>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   plano = pd.read_sql_query("SELECT codigo AS cod, nome AS  nome_plano, periodo AS  periodo_plano FROM plano", conexao)
#    cod nome_plano periodo_plano
# 0    1     bronze        mensal
# 1    2     silver    trimestral
# 2    3       gold     semestral
# 3    4   platinum         anual

# %%
atividade = pd.read_sql_query("SELECT codigo AS cod, nome AS descricao  FROM atividade", conexao)
atividade
# Out:
# <ipython-input-22-a0d38e1e70ff>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   atividade = pd.read_sql_query("SELECT codigo AS cod, nome AS descricao  FROM atividade", conexao)
#     cod             descricao
# 0     1            Musculação
# 1     2                 Zumba
# 2     3              crossfit
# 3     4  Acompanhamento dieta
# 4     5                  Yoga
# 5     6               Pilates
# 6     7             Fit Dance
# 7     8             Muay Thai
# 8     9                  Boxe
# 9    10              Spinning
# 10   11           Alongamento
# 11   12             Funcional
# 12   13           Bike Indoor
# 13   14                  Judo
# 14   15        Defesa pessoal

# %% [markdown]
# 9.4 CONSULTAS QUE USAM OPERADORES LIKE E DATAS (Mínimo 12)
#
# a) Criar outras 5 consultas que envolvam like ou ilike
#
# b) Criar uma consulta para cada tipo de função data apresentada.

# %% [markdown]
# a) Criar outras 5 consultas que envolvam like ou ilike

# %%
aluno_com_nome_carlos = pd.read_sql_query("SELECT * from pessoa where nome ilike '%carlos%'", conexao)
aluno_com_nome_carlos
# Out:
# <ipython-input-23-9b859113a11a>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   aluno_com_nome_carlos = pd.read_sql_query("SELECT * from pessoa where nome ilike '%carlos%'", conexao)
#    codigo           nome             cpf data_nascimento
# 0       8    Carlos Lima  123.321.456-09      1980-01-10
# 1     115  Carlos Mendes  720.300.400-80      1993-08-20

# %%
atividades_com_fit = pd.read_sql_query("SELECT * FROM atividade WHERE nome ILIKE '%fit'", conexao)
atividades_com_fit
# Out:
# <ipython-input-24-f0e7164f7a78>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   atividades_com_fit = pd.read_sql_query("SELECT * FROM atividade WHERE nome ILIKE '%fit'", conexao)
#    codigo      nome
# 0       3  crossfit

# %%
franquias_praca = pd.read_sql_query("SELECT * FROM franquia WHERE localizacao ILIKE '%cariacica%'", conexao)
franquias_praca
# Out:
# <ipython-input-29-9f6de92b8a1a>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   franquias_praca = pd.read_sql_query("SELECT * FROM franquia WHERE localizacao ILIKE '%cariacica%'", conexao)
#    codigo                       localizacao hora_abertura hora_fechamento
# 0       4  Cariacica, Jardim das Rosas, 520      08:00:00        23:00:00

# %%
atividades_com_A = pd.read_sql_query("SELECT * from atividade where nome like '%A%'",conexao);
atividades_com_A
# Out:
# <ipython-input-30-c0015dafc35b>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   atividades_com_A = pd.read_sql_query("SELECT * from atividade where nome like '%A%'",conexao);
#    codigo                  nome
# 0       4  Acompanhamento dieta
# 1      11           Alongamento

# %%
especialidade_lista_prof = pd.read_sql_query("SELECT p.especialidade, ps.nome from professor p inner join pessoa as ps on p.fk_pessoa_codigo = ps.codigo  where especialidade ilike '%musculação%'",conexao);
especialidade_lista_prof
# Out:
# <ipython-input-159-4272ca3fff78>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   especialidade_lista_prof = pd.read_sql_query("SELECT p.especialidade, ps.nome from professor p inner join pessoa as ps on p.fk_pessoa_codigo = ps.codigo  where especialidade ilike '%musculação%'",conexao);
#   especialidade            nome
# 0    Musculação  Felipe Azevedo
# 1    Musculação    Victor Costa

# %% [markdown]
# b) Criar uma consulta para cada tipo de função data apresentada.
#
# ---

# %%
pessoa_data_nascimento = pd.read_sql_query("SELECT nome,  DATE_PART('year', data_nascimento) AS ano_nascimento, DATE_PART('month', data_nascimento) AS mes_nascimento,    DATE_PART('day', data_nascimento) AS dia_nascimento FROM  pessoa ",conexao)
pessoa_data_nascimento
# Out:
# <ipython-input-32-e6dde74cb311>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pessoa_data_nascimento = pd.read_sql_query("SELECT nome,  DATE_PART('year', data_nascimento) AS ano_nascimento, DATE_PART('month', data_nascimento) AS mes_nascimento,    DATE_PART('day', data_nascimento) AS dia_nascimento FROM  pessoa ",conexao)
#                    nome  ano_nascimento  mes_nascimento  dia_nascimento
# 0            João Silva          1990.0             5.0            15.0
# 1          Maria Santos          1985.0             7.0            20.0
# 2           Pedro Souza          1998.0             2.0            10.0
# 3          Ana Oliveira          1977.0            11.0            25.0
# 4          José Pereira          2000.0             9.0             5.0
# ...

# %%
pessoa_idade = pd.read_sql_query ("SELECT nome, FLOOR(EXTRACT(YEAR FROM AGE(current_date, data_nascimento)))::INT as idade from pessoa", conexao)
pessoa_idade
# Out:
# <ipython-input-33-1403cf703b01>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pessoa_idade = pd.read_sql_query ("SELECT nome, FLOOR(EXTRACT(YEAR FROM AGE(current_date, data_nascimento)))::INT as idade from pessoa", conexao)
#                    nome  idade
# 0            João Silva     34
# 1          Maria Santos     39
# 2           Pedro Souza     26
# 3          Ana Oliveira     46
# 4          José Pereira     23
# ..                  ...    ...
# 115  Daniela Figueiredo     29
# 116     Emanuel Pereira     27
# 117        Flávia Souza     24
# 118    Geraldo Nogueira     36
# 119       Hilda Cardoso     34
#
# [120 rows x 2 columns]

# %%
pessoa_data_extract =pd.read_sql_query  ("SELECT nome, FLOOR(EXTRACT(YEAR FROM data_nascimento))::int AS ano_nascimento, FLOOR( EXTRACT(MONTH FROM data_nascimento))::int AS mes_nascimento, FLOOR(EXTRACT(DAY FROM data_nascimento))::int AS dia_nascimento FROM pessoa",conexao)
pessoa_data_extract
# Out:
# <ipython-input-34-2c3ea1cf8d16>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pessoa_data_extract =pd.read_sql_query  ("SELECT nome, FLOOR(EXTRACT(YEAR FROM data_nascimento))::int AS ano_nascimento, FLOOR( EXTRACT(MONTH FROM data_nascimento))::int AS mes_nascimento, FLOOR(EXTRACT(DAY FROM data_nascimento))::int AS dia_nascimento FROM pessoa",conexao)
#                    nome  ano_nascimento  mes_nascimento  dia_nascimento
# 0            João Silva            1990               5              15
# 1          Maria Santos            1985               7              20
# 2           Pedro Souza            1998               2              10
# 3          Ana Oliveira            1977              11              25
# 4          José Pereira            2000               9               5
# ...

# %%
data_nascimento_atual_idade = pd.read_sql_query  ("SELECT  nome, data_nascimento, CURRENT_DATE AS data_atual, FLOOR(EXTRACT(YEAR FROM AGE(CURRENT_DATE, data_nascimento)))::INT AS idade FROM  pessoa",conexao)
data_nascimento_atual_idade
# Out:
# <ipython-input-35-8c247bc1601e>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   data_nascimento_atual_idade = pd.read_sql_query  ("SELECT  nome, data_nascimento, CURRENT_DATE AS data_atual, FLOOR(EXTRACT(YEAR FROM AGE(CURRENT_DATE, data_nascimento)))::INT AS idade FROM  pessoa",conexao)
#                    nome data_nascimento  data_atual  idade
# 0            João Silva      1990-05-15  2024-08-06     34
# 1          Maria Santos      1985-07-20  2024-08-06     39
# 2           Pedro Souza      1998-02-10  2024-08-06     26
# 3          Ana Oliveira      1977-11-25  2024-08-06     46
# 4          José Pereira      2000-09-05  2024-08-06     23
# ..                  ...             ...         ...    ...
# 115  Daniela Figueiredo      1994-09-25  2024-08-06     29
# 116     Emanuel Pereira      1996-10-30  2024-08-06     27
# ...

# %%
plano_mes_julho = pd.read_sql_query("""SELECT  ap.codigo AS plano_codigo, a.fk_pessoa_codigo AS aluno_id, p.nome AS aluno_nome,  ap.data, to_char(CAST(CURRENT_TIME AS time), 'HH24:MI:SS') AS hora_atual FROM aluno_plano ap INNER JOIN aluno a ON ap.fk_aluno_fk_pessoa_codigo = a.fk_pessoa_codigo INNER JOIN pessoa p ON a.fk_pessoa_codigo = p.codigo WHERE EXTRACT(MONTH FROM ap.data) = 7 AND EXTRACT(YEAR FROM ap.data) = EXTRACT(YEAR FROM CURRENT_DATE)  ORDER BY ap.data""", conexao)
plano_mes_julho
# Out:
# <ipython-input-74-2f716d8f6f10>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   plano_mes_julho = pd.read_sql_query("""SELECT  ap.codigo AS plano_codigo, a.fk_pessoa_codigo AS aluno_id, p.nome AS aluno_nome,  ap.data, to_char(CAST(CURRENT_TIME AS time), 'HH24:MI:SS') AS hora_atual FROM aluno_plano ap INNER JOIN aluno a ON ap.fk_aluno_fk_pessoa_codigo = a.fk_pessoa_codigo INNER JOIN pessoa p ON a.fk_pessoa_codigo = p.codigo WHERE EXTRACT(MONTH FROM ap.data) = 7 AND EXTRACT(YEAR FROM ap.data) = EXTRACT(YEAR FROM CURRENT_DATE)  ORDER BY ap.data""", conexao)
#     plano_codigo  aluno_id         aluno_nome        data hora_atual
# 0              2         2       Maria Santos  2024-07-11   12:08:39
# 1              1         1         João Silva  2024-07-11   12:08:39
# ...

# %%
registros_alunos_do_mes = pd.read_sql_query ("SELECT  ap.codigo AS plano_codigo,  a.fk_pessoa_codigo AS aluno_id,  p.nome AS aluno_nome,  ap.data,  CURRENT_DATE AS data_consulta FROM aluno_plano ap INNER JOIN  aluno a ON ap.fk_aluno_fk_pessoa_codigo = a.fk_pessoa_codigo INNER JOIN pessoa p ON a.fk_pessoa_codigo = p.codigo WHERE EXTRACT(MONTH FROM ap.data) = EXTRACT(MONTH FROM CURRENT_DATE) AND EXTRACT(YEAR FROM ap.data) = EXTRACT(YEAR FROM CURRENT_DATE) ORDER BY  ap.data", conexao)
registros_alunos_do_mes
# Out:
# <ipython-input-87-fe77e3035261>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   registros_alunos_do_mes = pd.read_sql_query ("SELECT  ap.codigo AS plano_codigo,  a.fk_pessoa_codigo AS aluno_id,  p.nome AS aluno_nome,  ap.data,  CURRENT_DATE AS data_consulta FROM aluno_plano ap INNER JOIN  aluno a ON ap.fk_aluno_fk_pessoa_codigo = a.fk_pessoa_codigo INNER JOIN pessoa p ON a.fk_pessoa_codigo = p.codigo WHERE EXTRACT(MONTH FROM ap.data) = EXTRACT(MONTH FROM CURRENT_DATE) AND EXTRACT(YEAR FROM ap.data) = EXTRACT(YEAR FROM CURRENT_DATE) ORDER BY  ap.data", conexao)
#     plano_codigo  aluno_id         aluno_nome        data data_consulta
# 0             28        48       Mariana Dias  2024-08-01    2024-08-06
# 1             29        49   Nicolas Teixeira  2024-08-02    2024-08-06
# ...

# %%
dias_ate_data_atual = pd.read_sql_query ("SELECT ap.codigo AS plano_codigo, a.fk_pessoa_codigo AS aluno_id, p.nome AS aluno_nome,  ap.data AS data_plano, TO_CHAR(NOW(), 'YYYY-MM-DD HH24:MI:SS') AS data_hora_atual, EXTRACT(DAY FROM NOW() - ap.data) AS dias_ate_agora FROM aluno_plano ap INNER JOIN  aluno a ON ap.fk_aluno_fk_pessoa_codigo = a.fk_pessoa_codigo INNER JOIN pessoa p ON a.fk_pessoa_codigo = p.codigo WHERE EXTRACT(YEAR FROM ap.data) = EXTRACT(YEAR FROM NOW()) ORDER BY  ap.data;",conexao)
dias_ate_data_atual
# Out:
# <ipython-input-85-180f085aff2c>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dias_ate_data_atual = pd.read_sql_query ("SELECT ap.codigo AS plano_codigo, a.fk_pessoa_codigo AS aluno_id, p.nome AS aluno_nome,  ap.data AS data_plano, TO_CHAR(NOW(), 'YYYY-MM-DD HH24:MI:SS') AS data_hora_atual, EXTRACT(DAY FROM NOW() - ap.data) AS dias_ate_agora FROM aluno_plano ap INNER JOIN  aluno a ON ap.fk_aluno_fk_pessoa_codigo = a.fk_pessoa_codigo INNER JOIN pessoa p ON a.fk_pessoa_codigo = p.codigo WHERE EXTRACT(YEAR FROM ap.data) = EXTRACT(YEAR FROM NOW()) ORDER BY  ap.data;",conexao)
#     plano_codigo  aluno_id        aluno_nome  data_plano      data_hora_atual  \
# 0              8        18     Diogo Almeida  2024-02-17  2024-08-06 12:26:57
# 1             13        22     Helena Farias  2024-03-14  2024-08-06 12:26:57
# ...

# %% [markdown]
# 9.5 INSTRUÇÕES APLICANDO ATUALIZAÇÃO E EXCLUSÃO DE DADOS (Mínimo 6)
#
# a) Criar minimo 3 de exclusão
#
# b) Criar minimo 3 de atualização

# %% [markdown]
# a) Criar minimo 3 de exclusão

# %%
exclusao_atividade = pd.read_sql_query ("DELETE FROM atividade WHERE codigo = 15", conexao)
exclusao_atividade

# %%
exclusao_aluno = pd.read_sql_query ("DELETE FROM aluno WHERE fk_pessoa_codigo = 23", conexao)
exclusao_aluno

# %%
exclusao_franquia = pd.read_sql_query ("DELETE FROM franquia WHERE codigo = 5", conexao)
exclusao_franquia

# %% [markdown]
# b) Criar minimo 3 de atualização

# %%
update_ativdade = pd.read_sql_query ("UPDATE atividade SET nome = 'Karatê' WHERE codigo = 14", conexao)
update_ativdade

# %%
update_aluno = pd.read_sql_query ("UPDATE aluno SET peso = 70.0 WHERE fk_pessoa_codigo = 22", conexao)
update_aluno

# %%
update_franquia = pd.read_sql_query ("UPDATE franquia SET hora_fechamento = '23:30:00' WHERE codigo = 4", conexao)
update_franquia

# %% [markdown]
# 9.6 CONSULTAS COM INNER JOIN E ORDER BY (Mínimo 6)
#
# a) Uma junção que envolva todas as tabelas possuindo no mínimo 2 registros no resultado
#
# b) Outras junções que o grupo considere como sendo as de principal importância para o trabalho

# %% [markdown]
# a) Uma junção que envolva todas as tabelas possuindo no mínimo 2 registros no resultado

# %%
todas_tabelas = pd.read_sql_query ("SELECT p_aluno.nome AS nome_aluno, pl.nome AS plano_aluno, p_prof.nome AS nome_professor, f.localizacao AS local_franquia, a_atividade.nome AS atividade_realizada FROM  ALUNO a INNER JOIN PESSOA p_aluno ON p_aluno.codigo = a.FK_PESSOA_codigo INNER JOIN ALUNO_PLANO ap ON a.FK_PESSOA_codigo = ap.FK_ALUNO_FK_PESSOA_codigo INNER JOIN PLANO pl ON ap.FK_PLANO_codigo = pl.codigo INNER JOIN ALUNO_FRANQUIA af ON a.FK_PESSOA_codigo = af.fk_ALUNO_FK_PESSOA_codigo INNER JOIN FRANQUIA f ON af.fk_FRANQUIA_codigo = f.codigo INNER JOIN ATIVIDADE_FRANQUIA afq ON f.codigo = afq.fk_FRANQUIA_codigo INNER JOIN ATIVIDADE a_atividade ON afq.fk_ATIVIDADE_codigo = a_atividade.codigo INNER JOIN PROFESSOR_ATIVIDADE pa ON a_atividade.codigo = pa.fk_ATIVIDADE_codigo INNER JOIN PESSOA p_prof ON p_prof.codigo = pa.fk_PROFESSOR_FK_PESSOA_codigo;", conexao)
todas_tabelas
# Out:
# <ipython-input-88-172f179f7a33>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
# ...

# %% [markdown]
# b) Outras junções que o grupo considere como sendo as de principal importância para o trabalho

# %%
franquia_aluno = pd.read_sql_query ("SELECT franquia.localizacao AS localizacao_da_franquia, COUNT(DISTINCT aluno_franquia.fk_aluno_fk_pessoa_codigo) AS quantidade_de_alunos FROM aluno_franquia INNER JOIN franquia ON franquia.codigo = aluno_franquia.fk_franquia_codigo GROUP BY franquia.localizacao ORDER BY franquia.localizacao ASC;", conexao)
franquia_aluno
# Out:
# <ipython-input-96-767089a42f3a>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   franquia_aluno = pd.read_sql_query ("SELECT franquia.localizacao AS localizacao_da_franquia, COUNT(DISTINCT aluno_franquia.fk_aluno_fk_pessoa_codigo) AS quantidade_de_alunos FROM aluno_franquia INNER JOIN franquia ON franquia.codigo = aluno_franquia.fk_franquia_codigo GROUP BY franquia.localizacao ORDER BY franquia.localizacao ASC;", conexao)
#                      localizacao_da_franquia  quantidade_de_alunos
# 0         Campo Grande, Avenida Central, 456                     6
# 1           Cariacica, Jardim das Rosas, 520                     9
# 2                 Centro, Rua Principal, 123                     6
# 3                Cobilândia, Rua do Sol, 707                    10
# ...

# %%
registros_alunos_franquia = pd.read_sql_query("select pessoa.nome as aluno, pessoa.cpf, franquia.localizacao as localizacao_da_franquia, aluno_franquia.data_hora_inicio as entrada_na_franquia, aluno_franquia.data_hora_fim as saida_da_franquia from pessoa inner join aluno_franquia on pessoa.codigo = aluno_franquia.fk_aluno_fk_pessoa_codigo inner join franquia on franquia.codigo = aluno_franquia.fk_franquia_codigo group by pessoa.nome, pessoa.cpf, aluno_franquia.data_hora_inicio, aluno_franquia.data_hora_fim, franquia.localizacao",conexao)
registros_alunos_franquia
# Out:
# <ipython-input-60-93cd803f8d0d>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   registros_alunos_franquia = pd.read_sql_query("select pessoa.nome as aluno, pessoa.cpf, franquia.localizacao as localizacao_da_franquia, aluno_franquia.data_hora_inicio as entrada_na_franquia, aluno_franquia.data_hora_fim as saida_da_franquia from pessoa inner join aluno_franquia on pessoa.codigo = aluno_franquia.fk_aluno_fk_pessoa_codigo inner join franquia on franquia.codigo = aluno_franquia.fk_franquia_codigo group by pessoa.nome, pessoa.cpf, aluno_franquia.data_hora_inicio, aluno_franquia.data_hora_fim, franquia.localizacao",conexao)
#                 aluno             cpf            localizacao_da_franquia  \
# 0          Igor Sousa  753.852.159-12    Eurico Salles, Santa Clara, 351
# ...

# %%
professores_especialidade = pd.read_sql_query ("SELECT  p.nome AS professor_nome, p.cpf AS professor_cpf, p.data_nascimento AS professor_data_nascimento,  prof.especialidade AS professor_especialidade,   f.localizacao AS franquia_localizacao FROM  pessoa p   INNER JOIN professor prof ON p.codigo = prof.fk_pessoa_codigo   INNER JOIN professor_franquia pf ON prof.fk_pessoa_codigo = pf.fk_professor_fk_pessoa_codigo INNER JOIN franquia f ON pf.fk_franquia_codigo = f.codigo ORDER BY  p.nome", conexao)
professores_especialidade
# Out:
# <ipython-input-61-650c0f22453d>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   professores_especialidade = pd.read_sql_query ("SELECT  p.nome AS professor_nome, p.cpf AS professor_cpf, p.data_nascimento AS professor_data_nascimento,  prof.especialidade AS professor_especialidade,   f.localizacao AS franquia_localizacao FROM  pessoa p   INNER JOIN professor prof ON p.codigo = prof.fk_pessoa_codigo   INNER JOIN professor_franquia pf ON prof.fk_pessoa_codigo = pf.fk_professor_fk_pessoa_codigo INNER JOIN franquia f ON pf.fk_franquia_codigo = f.codigo ORDER BY  p.nome", conexao)
#       professor_nome   professor_cpf professor_data_nascimento  \
# 0       Ana Oliveira  321.654.987-00                1977-11-25
# 1       Ana Oliveira  321.654.987-00                1977-11-25
# ...

# %%
atividades_franquias = pd.read_sql_query (" SELECT a.nome AS atividade_nome, p.nome AS professor_nome,  f.localizacao AS franquia_localizacao FROM atividade a INNER JOIN professor_atividade pa ON a.codigo = pa.fk_atividade_codigo INNER JOIN professor pr ON pa.fk_professor_fk_pessoa_codigo = pr.fk_pessoa_codigo  INNER JOIN pessoa p ON pr.fk_pessoa_codigo = p.codigo INNER JOIN atividade_franquia af ON a.codigo = af.fk_atividade_codigo  INNER JOIN franquia f ON af.fk_franquia_codigo = f.codigo ORDER BY  a.nome, p.nome, f.localizacao", conexao)
atividades_franquias
# Out:
# <ipython-input-62-95205f401e86>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   atividades_franquias = pd.read_sql_query (" SELECT a.nome AS atividade_nome, p.nome AS professor_nome,  f.localizacao AS franquia_localizacao FROM atividade a INNER JOIN professor_atividade pa ON a.codigo = pa.fk_atividade_codigo INNER JOIN professor pr ON pa.fk_professor_fk_pessoa_codigo = pr.fk_pessoa_codigo  INNER JOIN pessoa p ON pr.fk_pessoa_codigo = p.codigo INNER JOIN atividade_franquia af ON a.codigo = af.fk_atividade_codigo  INNER JOIN franquia f ON af.fk_franquia_codigo = f.codigo ORDER BY  a.nome, p.nome, f.localizacao", conexao)
#            atividade_nome professor_nome  \
# 0    Acompanhamento dieta  Fernando Lima
# 1    Acompanhamento dieta  Fernando Lima
# 2    Acompanhamento dieta  Fernando Lima
# ...

# %%
receita_planos = pd.read_sql_query ("SELECT  pl.nome AS plano_nome, pl.periodo AS plano_periodo, ap.valor AS valor_por_aluno,  COUNT(ap.codigo) AS numero_alunos, COALESCE(SUM(ap.valor), 0) AS receita_gerada FROM plano pl LEFT JOIN aluno_plano ap ON pl.codigo = ap.fk_plano_codigo GROUP BY pl.nome, pl.periodo, ap.valor ORDER BY  pl.nome", conexao)
receita_planos
# Out:
# <ipython-input-63-44b59816272c>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   receita_planos = pd.read_sql_query ("SELECT  pl.nome AS plano_nome, pl.periodo AS plano_periodo, ap.valor AS valor_por_aluno,  COUNT(ap.codigo) AS numero_alunos, COALESCE(SUM(ap.valor), 0) AS receita_gerada FROM plano pl LEFT JOIN aluno_plano ap ON pl.codigo = ap.fk_plano_codigo GROUP BY pl.nome, pl.periodo, ap.valor ORDER BY  pl.nome", conexao)
#   plano_nome plano_periodo  valor_por_aluno  numero_alunos  receita_gerada
# 0     bronze        mensal             80.0             26          2080.0
# 1       gold     semestral            500.0             24         12000.0
# 2   platinum         anual            900.0             25         22500.0
# 3     silver    trimestral            300.0             25          7500.0

# %% [markdown]
# 9.7 CONSULTAS COM GROUP BY E FUNÇÕES DE AGRUPAMENTO (Mínimo 6)
#
# a) Criar minimo 2 envolvendo algum tipo de junção

# %%
plano_qtd_aluno = pd.read_sql_query("select plano.nome as nome_do_plano, count(aluno_plano.fk_aluno_fk_pessoa_codigo) as quantidade_de_alunos from aluno_plano inner join plano on plano.codigo = aluno_plano.fk_plano_codigo group by plano.nome order by plano.nome asc",conexao)
plano_qtd_aluno
# Out:
# <ipython-input-64-ff4019e4fdb6>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   plano_qtd_aluno = pd.read_sql_query("select plano.nome as nome_do_plano, count(aluno_plano.fk_aluno_fk_pessoa_codigo) as quantidade_de_alunos from aluno_plano inner join plano on plano.codigo = aluno_plano.fk_plano_codigo group by plano.nome order by plano.nome asc",conexao)
#   nome_do_plano  quantidade_de_alunos
# 0        bronze                    26
# 1          gold                    24
# 2      platinum                    25
# 3        silver                    25

# %%
valor_total_plano = pd.read_sql_query ("SELECT p.nome AS plano_nome, SUM(ap.valor) AS total_receita FROM  plano p  INNER JOIN aluno_plano ap ON p.codigo = ap.fk_plano_codigo GROUP BY  p.nome;",conexao)
valor_total_plano
# Out:
# <ipython-input-65-a23f8a0a30b2>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   valor_total_plano = pd.read_sql_query ("SELECT p.nome AS plano_nome, SUM(ap.valor) AS total_receita FROM  plano p  INNER JOIN aluno_plano ap ON p.codigo = ap.fk_plano_codigo GROUP BY  p.nome;",conexao)
#   plano_nome  total_receita
# 0       gold        12000.0
# 1     silver         7500.0
# 2     bronze         2080.0
# 3   platinum        22500.0

# %%
alunos_por_franquia_tipo_de_plano = pd.read_sql_query ("SELECT  f.localizacao AS franquia_localizacao, p.nome AS nome_plano,COUNT(ap.fk_aluno_fk_pessoa_codigo) AS total_alunos FROM  franquia f LEFT JOIN aluno_franquia af ON f.codigo = af.fk_franquia_codigo LEFT JOIN  aluno_plano ap ON af.fk_aluno_fk_pessoa_codigo = ap.fk_aluno_fk_pessoa_codigo LEFT JOIN plano p ON ap.fk_plano_codigo = p.codigo GROUP BY  f.codigo, f.localizacao, p.codigo, p.nome ORDER BY  f.localizacao, p.nome",conexao)
alunos_por_franquia_tipo_de_plano
# Out:
# <ipython-input-66-7f7dafcfe423>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   alunos_por_franquia_tipo_de_plano = pd.read_sql_query ("SELECT  f.localizacao AS franquia_localizacao, p.nome AS nome_plano,COUNT(ap.fk_aluno_fk_pessoa_codigo) AS total_alunos FROM  franquia f LEFT JOIN aluno_franquia af ON f.codigo = af.fk_franquia_codigo LEFT JOIN  aluno_plano ap ON af.fk_aluno_fk_pessoa_codigo = ap.fk_aluno_fk_pessoa_codigo LEFT JOIN plano p ON ap.fk_plano_codigo = p.codigo GROUP BY  f.codigo, f.localizacao, p.codigo, p.nome ORDER BY  f.localizacao, p.nome",conexao)
#                         franquia_localizacao nome_plano  total_alunos
# 0         Campo Grande, Avenida Central, 456   platinum             2
# 1         Campo Grande, Avenida Central, 456     silver             4
# ...

# %%
maximo_valor_pago_aluno_franquia = pd.read_sql_query ("SELECT F.localizacao AS Franquia, MAX(AP.valor) AS Valor_Maximo FROM FRANQUIA F INNER JOIN ALUNO_FRANQUIA AF ON F.codigo = AF.fk_FRANQUIA_codigo INNER JOIN ALUNO A ON AF.fk_ALUNO_FK_PESSOA_codigo = A.FK_PESSOA_codigo INNER JOIN ALUNO_PLANO AP ON A.FK_PESSOA_codigo = AP.FK_ALUNO_FK_PESSOA_codigo GROUP BY F.localizacao;",conexao)
maximo_valor_pago_aluno_franquia
# Out:
# <ipython-input-67-22f6801038bc>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   maximo_valor_pago_aluno_franquia = pd.read_sql_query ("SELECT F.localizacao AS Franquia, MAX(AP.valor) AS Valor_Maximo FROM FRANQUIA F INNER JOIN ALUNO_FRANQUIA AF ON F.codigo = AF.fk_FRANQUIA_codigo INNER JOIN ALUNO A ON AF.fk_ALUNO_FK_PESSOA_codigo = A.FK_PESSOA_codigo INNER JOIN ALUNO_PLANO AP ON A.FK_PESSOA_codigo = AP.FK_ALUNO_FK_PESSOA_codigo GROUP BY F.localizacao;",conexao)
#                                     franquia  valor_maximo
# 0         Campo Grande, Avenida Central, 456         900.0
# 1         Jardim da Penha, Rua do Lazer, 202         500.0
# 2           Cariacica, Jardim das Rosas, 520         900.0
# 3              Nova Almeida, Rua do Mar, 404         900.0
# 4                 Laranjeiras, Jardim A, 123         900.0
# ...

# %%
minimo_valor_pago_aluno_franquia = pd.read_sql_query ("SELECT F.localizacao AS Franquia, MIN(AP.valor) AS Valor_minimo FROM FRANQUIA F INNER JOIN ALUNO_FRANQUIA AF ON F.codigo = AF.fk_FRANQUIA_codigo INNER JOIN ALUNO A ON AF.fk_ALUNO_FK_PESSOA_codigo = A.FK_PESSOA_codigo INNER JOIN ALUNO_PLANO AP ON A.FK_PESSOA_codigo = AP.FK_ALUNO_FK_PESSOA_codigo GROUP BY F.localizacao;",conexao)
minimo_valor_pago_aluno_franquia
# Out:
# <ipython-input-68-a487c83731d3>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   minimo_valor_pago_aluno_franquia = pd.read_sql_query ("SELECT F.localizacao AS Franquia, MIN(AP.valor) AS Valor_minimo FROM FRANQUIA F INNER JOIN ALUNO_FRANQUIA AF ON F.codigo = AF.fk_FRANQUIA_codigo INNER JOIN ALUNO A ON AF.fk_ALUNO_FK_PESSOA_codigo = A.FK_PESSOA_codigo INNER JOIN ALUNO_PLANO AP ON A.FK_PESSOA_codigo = AP.FK_ALUNO_FK_PESSOA_codigo GROUP BY F.localizacao;",conexao)
#                                     franquia  valor_minimo
# 0         Campo Grande, Avenida Central, 456         300.0
# 1         Jardim da Penha, Rua do Lazer, 202          80.0
# 2           Cariacica, Jardim das Rosas, 520          80.0
# 3              Nova Almeida, Rua do Mar, 404          80.0
# 4                 Laranjeiras, Jardim A, 123          80.0
# ...

# %%
media_valores_pago_aluno = pd.read_sql_query ("SELECT F.localizacao AS Franquia, AVG(AP.valor) AS media_valor FROM FRANQUIA F INNER JOIN ALUNO_FRANQUIA AF ON F.codigo = AF.fk_FRANQUIA_codigo INNER JOIN ALUNO A ON AF.fk_ALUNO_FK_PESSOA_codigo = A.FK_PESSOA_codigo INNER JOIN ALUNO_PLANO AP ON A.FK_PESSOA_codigo = AP.FK_ALUNO_FK_PESSOA_codigo GROUP BY F.localizacao;",conexao)
media_valores_pago_aluno
# Out:
# <ipython-input-69-0ed4662af3b1>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   media_valores_pago_aluno = pd.read_sql_query ("SELECT F.localizacao AS Franquia, AVG(AP.valor) AS media_valor FROM FRANQUIA F INNER JOIN ALUNO_FRANQUIA AF ON F.codigo = AF.fk_FRANQUIA_codigo INNER JOIN ALUNO A ON AF.fk_ALUNO_FK_PESSOA_codigo = A.FK_PESSOA_codigo INNER JOIN ALUNO_PLANO AP ON A.FK_PESSOA_codigo = AP.FK_ALUNO_FK_PESSOA_codigo GROUP BY F.localizacao;",conexao)
#                                     franquia  media_valor
# 0         Campo Grande, Avenida Central, 456   500.000000
# 1         Jardim da Penha, Rua do Lazer, 202   290.000000
# 2           Cariacica, Jardim das Rosas, 520   456.000000
# 3              Nova Almeida, Rua do Mar, 404   290.000000
# 4                 Laranjeiras, Jardim A, 123   456.363636
# ...

# %% [markdown]
# 9.8 CONSULTAS COM LEFT, RIGHT E FULL JOIN (Mínimo 4)
#
# a) Criar minimo 1 de cada tipo

# %%
franquias_aluno = pd.read_sql_query ("SELECT F.localizacao AS Local_Franquia, P.nome AS Nome_Aluno, A.peso AS Peso_Aluno FROM FRANQUIA F LEFT JOIN ALUNO_FRANQUIA AF ON F.codigo = AF.fk_FRANQUIA_codigo inner JOIN ALUNO A ON AF.fk_ALUNO_FK_PESSOA_codigo = A.FK_PESSOA_codigo inner JOIN PESSOA P ON A.FK_PESSOA_codigo = P.codigo ORDER BY F.localizacao;",conexao)
franquias_aluno
# Out:
# <ipython-input-70-1e2b0d084be4>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   franquias_aluno = pd.read_sql_query ("SELECT F.localizacao AS Local_Franquia, P.nome AS Nome_Aluno, A.peso AS Peso_Aluno FROM FRANQUIA F LEFT JOIN ALUNO_FRANQUIA AF ON F.codigo = AF.fk_FRANQUIA_codigo inner JOIN ALUNO A ON AF.fk_ALUNO_FK_PESSOA_codigo = A.FK_PESSOA_codigo inner JOIN PESSOA P ON A.FK_PESSOA_codigo = P.codigo ORDER BY F.localizacao;",conexao)
#                          local_franquia        nome_aluno  peso_aluno
# 0    Campo Grande, Avenida Central, 456     Mariana Costa        75.5
# 1    Campo Grande, Avenida Central, 456    Bernardo Costa        60.0
# 2    Campo Grande, Avenida Central, 456  Patrícia Martins        72.0
# 3    Campo Grande, Avenida Central, 456     Fabio Cardoso        74.0
# ...

# %%
franquias_aluno_right = pd.read_sql_query ("SELECT F.localizacao AS Local_Franquia, P.nome AS Nome_Aluno, A.peso AS Peso_Aluno FROM FRANQUIA F Right JOIN ALUNO_FRANQUIA AF ON F.codigo = AF.fk_FRANQUIA_codigo right JOIN ALUNO A ON AF.fk_ALUNO_FK_PESSOA_codigo = A.FK_PESSOA_codigo inner JOIN PESSOA P ON A.FK_PESSOA_codigo = P.codigo ORDER BY F.localizacao;",conexao)
franquias_aluno_right
# Out:
# <ipython-input-71-ee56ffae02e3>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   franquias_aluno_right = pd.read_sql_query ("SELECT F.localizacao AS Local_Franquia, P.nome AS Nome_Aluno, A.peso AS Peso_Aluno FROM FRANQUIA F Right JOIN ALUNO_FRANQUIA AF ON F.codigo = AF.fk_FRANQUIA_codigo right JOIN ALUNO A ON AF.fk_ALUNO_FK_PESSOA_codigo = A.FK_PESSOA_codigo inner JOIN PESSOA P ON A.FK_PESSOA_codigo = P.codigo ORDER BY F.localizacao;",conexao)
#                          local_franquia        nome_aluno  peso_aluno
# 0    Campo Grande, Avenida Central, 456    Leonardo Silva        71.0
# 1    Campo Grande, Avenida Central, 456     Mariana Costa        75.5
# 2    Campo Grande, Avenida Central, 456    Bernardo Costa        60.0
# 3    Campo Grande, Avenida Central, 456  Patrícia Martins        72.0
# ...

# %%
atividades_right = pd.read_sql_query ("SELECT f.localizacao AS franquia_localizacao, a.nome AS atividade_nome FROM atividade a RIGHT JOIN atividade_franquia af ON a.codigo = af.fk_atividade_codigo RIGHT JOIN franquia f ON af.fk_franquia_codigo = f.codigo ORDER BY f.localizacao, a.nome;",conexao)
atividades_right
# Out:
# <ipython-input-72-150c757f8867>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   atividades_right = pd.read_sql_query ("SELECT f.localizacao AS franquia_localizacao, a.nome AS atividade_nome FROM atividade a RIGHT JOIN atividade_franquia af ON a.codigo = af.fk_atividade_codigo RIGHT JOIN franquia f ON af.fk_franquia_codigo = f.codigo ORDER BY f.localizacao, a.nome;",conexao)
#                   franquia_localizacao        atividade_nome
# 0   Campo Grande, Avenida Central, 456  Acompanhamento dieta
# 1   Campo Grande, Avenida Central, 456             Fit Dance
# 2   Campo Grande, Avenida Central, 456               Pilates
# 3   Campo Grande, Avenida Central, 456                  Yoga
# 4     Cariacica, Jardim das Rosas, 520  Acompanhamento dieta
# ..                                 ...                   ...
# ...

# %%
especialidade_full = pd.read_sql_query ("select pessoa.codigo, pessoa.nome, pessoa.cpf, pessoa.data_nascimento, professor.especialidade from pessoa full join professor on pessoa.codigo = professor.fk_pessoa_codigo group by pessoa.codigo, pessoa.nome, pessoa.cpf, pessoa.data_nascimento, professor.fk_pessoa_codigo order by pessoa.codigo asc",conexao)
especialidade_full
# Out:
# <ipython-input-73-33ebedd38686>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   especialidade_full = pd.read_sql_query ("select pessoa.codigo, pessoa.nome, pessoa.cpf, pessoa.data_nascimento, professor.especialidade from pessoa full join professor on pessoa.codigo = professor.fk_pessoa_codigo group by pessoa.codigo, pessoa.nome, pessoa.cpf, pessoa.data_nascimento, professor.fk_pessoa_codigo order by pessoa.codigo asc",conexao)
#      codigo                nome             cpf data_nascimento  \
# 0         1          João Silva  123.456.789-00      1990-05-15
# 1         2        Maria Santos  987.654.321-00      1985-07-20
# 2         3         Pedro Souza  456.789.123-00      1998-02-10
# 3         4        Ana Oliveira  321.654.987-00      1977-11-25
# 4         5        José Pereira  789.123.456-00      2000-09-05
# ...

# %%
alunos_por_franquias = pd.read_sql_query ("select franquia.localizacao as localizacao_das_academias, count(aluno_franquia.fk_aluno_fk_pessoa_codigo) as alunos_por_franquias from franquia inner join aluno_franquia on franquia.codigo = aluno_franquia.fk_franquia_codigo group by franquia.localizacao ", conexao)
alunos_por_franquias
# Out:
# <ipython-input-74-9efa1da5da70>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   alunos_por_franquias = pd.read_sql_query ("select franquia.localizacao as localizacao_das_academias, count(aluno_franquia.fk_aluno_fk_pessoa_codigo) as alunos_por_franquias from franquia inner join aluno_franquia on franquia.codigo = aluno_franquia.fk_franquia_codigo group by franquia.localizacao ", conexao)
#                    localizacao_das_academias  alunos_por_franquias
# 0         Campo Grande, Avenida Central, 456                     6
# 1         Jardim da Penha, Rua do Lazer, 202                     6
# 2           Cariacica, Jardim das Rosas, 520                    10
# 3              Nova Almeida, Rua do Mar, 404                    10
# 4                 Laranjeiras, Jardim A, 123                    11
# ...

# %% [markdown]
# 9.9 CONSULTAS COM SELF JOIN E VIEW (Mínimo 6)
#
#     a) Uma junção que envolva Self Join (caso não ocorra na base justificar e substituir por uma view)
#
#     b) Outras junções com views que o grupo considere como sendo de relevante importância para o trabalho

# %% [markdown]
#     a) Uma junção que envolva Self Join (caso não ocorra na base justificar e substituir por uma view)
#
#     Justificativa: Não tem colunas que referenciam outras numa mesma tabela.

# %%
qtd_franquia_aluno = pd.read_sql_query ("CREATE VIEW Franquia_Quantidade_Alunos AS SELECT F.localizacao AS Franquia, COUNT(AF.fk_ALUNO_FK_PESSOA_codigo) AS Quantidade_Alunos FROM FRANQUIA F LEFT JOIN ALUNO_FRANQUIA AF ON F.codigo = AF.fk_FRANQUIA_codigo GROUP BY F.localizacao;", conexao)

# %%
qtd_franquia_aluno_view = pd.read_sql_query ("SELECT * FROM Franquia_Quantidade_Alunos", conexao)
qtd_franquia_aluno_view

# %% [markdown]
#    b) Outras junções com views que o grupo considere como sendo de relevante importância para o trabalho

# %%
dados_aluno_ingresso = pd.read_sql_query ("	CREATE VIEW relatorio_alunos_por_plano AS SELECT P.nome AS Aluno, P.cpf AS CPF, P.data_nascimento AS Data_Nascimento, A.altura AS Altura, A.peso AS Peso, PL.nome AS Plano, PL.periodo AS Plano_Periodo, AP.valor AS Valor_Plano, AP.data AS Data_Assinatura	FROM ALUNO A INNER JOIN PESSOA P ON A.FK_PESSOA_codigo = P.codigo	INNER JOIN ALUNO_PLANO AP ON A.FK_PESSOA_codigo = AP.FK_ALUNO_FK_PESSOA_codigo INNER JOIN PLANO PL ON AP.FK_PLANO_codigo = PL.codigo;", conexao)

# %%
dados_aluno_ingresso_view = pd.read_sql_query ("SELECT * FROM relatorio_alunos_por_plano", conexao)
dados_aluno_ingresso_view

# %%
dados_atividades_franquias = pd.read_sql_query ("create view atividades_franquias as SELECT F.localizacao AS Local_Franquia, A.nome AS NomeAtividade FROM FRANQUIA F INNER JOIN ATIVIDADE_FRANQUIA AF ON F.codigo = AF.fk_FRANQUIA_codigo INNER JOIN ATIVIDADE A ON AF.fk_ATIVIDADE_codigo = A.codigo;", conexao)

# %%
dados_atividades_franquias_view = pd.read_sql_query ("SELECT * FROM atividades_franquias order by Local_Franquia", conexao)
dados_atividades_franquias_view

# %%
relatorio_ponto_professor_view = pd.read_sql_query ("CREATE VIEW Professor_Franquia_Ponto AS SELECT P.nome AS Professor, F.localizacao AS Franquia, PF.data_hora_inicio AS DataHora_Inicio, PF.data_hora_fim AS DataHora_Fim FROM PROFESSOR_FRANQUIA PF INNER JOIN PROFESSOR PR ON PF.fk_PROFESSOR_FK_PESSOA_codigo = PR.FK_PESSOA_codigo INNER JOIN PESSOA P ON PR.FK_PESSOA_codigo = P.codigo INNER JOIN FRANQUIA F ON PF.fk_FRANQUIA_codigo = F.codigo;", conexao)
relatorio_ponto_professor_view

# %%
dados_ponto_franquia = pd.read_sql_query ("SELECT * FROM Professor_Franquia_Ponto", conexao)
dados_ponto_franquia

# %%
dados_ponto_aluno_view = pd.read_sql_query ("create view relatorio_aluno_ponto as select pessoa.nome as nome_pessoa, pessoa.cpf, franquia.localizacao as localizacao_da_franquia, aluno_franquia.data_hora_inicio as entrada_na_franquia, aluno_franquia.data_hora_fim as saida_da_franquia from pessoa inner join aluno_franquia on pessoa.codigo = aluno_franquia.fk_aluno_fk_pessoa_codigo inner join franquia on franquia.codigo = aluno_franquia.fk_franquia_codigo group by pessoa.nome, pessoa.cpf, aluno_franquia.data_hora_inicio, aluno_franquia.data_hora_fim, franquia.localizacao;", conexao)
dados_ponto_aluno_view

# %%
dados_ponto_aluno = pd.read_sql_query ("SELECT * FROM relatorio_aluno_ponto", conexao)
dados_ponto_aluno

# %%
dados_receita_franquia_view = pd.read_sql_query ("CREATE VIEW Receita_Franquia AS SELECT F.localizacao AS Franquia, SUM(AP.valor) AS Receita_Total FROM FRANQUIA F INNER JOIN ALUNO_FRANQUIA AF ON F.codigo = AF.fk_FRANQUIA_codigo INNER JOIN ALUNO A ON AF.fk_ALUNO_FK_PESSOA_codigo = A.FK_PESSOA_codigo INNER JOIN ALUNO_PLANO AP ON A.FK_PESSOA_codigo = AP.FK_ALUNO_FK_PESSOA_codigo GROUP BY F.localizacao;", conexao)
dados_receita_franquia_view

# %%
dados_receita_franquia = pd.read_sql_query ("SELECT * FROM Receita_Franquia", conexao)
dados_receita_franquia

# %% [markdown]
# 9.10 SUBCONSULTAS (Mínimo 4)
#
#  a) Criar minimo 1 envolvendo GROUP BY
#
#  b) Criar minimo 1 envolvendo algum tipo de junção

# %% [markdown]
#  a) Criar minimo 1 envolvendo GROUP BY

# %%
total_alunos_platinum_por_franquia = pd.read_sql_query ("SELECT f.localizacao AS franquia_localizacao, COUNT(ap.fk_aluno_fk_pessoa_codigo) AS total_alunos_platinum, (SELECT COUNT(af_inner.fk_aluno_fk_pessoa_codigo) FROM aluno_franquia af_inner WHERE af_inner.fk_franquia_codigo = f.codigo) AS total_alunos FROM franquia f LEFT JOIN aluno_franquia af ON f.codigo = af.fk_franquia_codigo LEFT JOIN aluno_plano ap ON af.fk_aluno_fk_pessoa_codigo = ap.fk_aluno_fk_pessoa_codigo WHERE ap.fk_plano_codigo = 4 GROUP BY f.codigo, f.localizacao ORDER BY f.localizacao", conexao)
total_alunos_platinum_por_franquia
# Out:
# <ipython-input-75-ed2095720c5a>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   total_alunos_platinum_por_franquia = pd.read_sql_query ("SELECT f.localizacao AS franquia_localizacao, COUNT(ap.fk_aluno_fk_pessoa_codigo) AS total_alunos_platinum, (SELECT COUNT(af_inner.fk_aluno_fk_pessoa_codigo) FROM aluno_franquia af_inner WHERE af_inner.fk_franquia_codigo = f.codigo) AS total_alunos FROM franquia f LEFT JOIN aluno_franquia af ON f.codigo = af.fk_franquia_codigo LEFT JOIN aluno_plano ap ON af.fk_aluno_fk_pessoa_codigo = ap.fk_aluno_fk_pessoa_codigo WHERE ap.fk_plano_codigo = 4 GROUP BY f.codigo, f.localizacao ORDER BY f.localizacao", conexao)
#                         franquia_localizacao  total_alunos_platinum  \
# 0         Campo Grande, Avenida Central, 456                      2
# ...

# %%
professores_em_franquias = pd.read_sql_query ("SELECT f.localizacao AS franquia_localizacao, (SELECT COUNT(*) FROM professor_franquia pf WHERE pf.fk_franquia_codigo = f.codigo) AS total_professores FROM franquia f;", conexao)
professores_em_franquias
# Out:
# <ipython-input-76-d4e8dcde16d3>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   professores_em_franquias = pd.read_sql_query ("SELECT f.localizacao AS franquia_localizacao, (SELECT COUNT(*) FROM professor_franquia pf WHERE pf.fk_franquia_codigo = f.codigo) AS total_professores FROM franquia f;", conexao)
#                         franquia_localizacao  total_professores
# 0                 Laranjeiras, Jardim A, 123                  6
# 1          Jardim Camburi,  Praça Verde, 456                  7
# 2   Praia do Canto, Praia das Estrelas, 1252                  6
# 3           Cariacica, Jardim das Rosas, 520                  4
# 4            Eurico Salles, Santa Clara, 351                  5
# 5                 Centro, Rua Principal, 123                  1
# 6         Campo Grande, Avenida Central, 456                  1
# ...

# %% [markdown]
#  b) Criar minimo 1 envolvendo algum tipo de junção

# %%
frequencia_aluno = pd.read_sql_query ("SELECT p.nome AS aluno_nome, f.localizacao AS franquia_localizacao, pl.nome AS plano_nome, af.data_hora_inicio, af.data_hora_fim FROM aluno a JOIN pessoa p ON a.fk_pessoa_codigo = p.codigo JOIN aluno_franquia af ON a.fk_pessoa_codigo = af.fk_aluno_fk_pessoa_codigo JOIN franquia f ON af.fk_franquia_codigo = f.codigo JOIN aluno_plano ap ON a.fk_pessoa_codigo = ap.fk_aluno_fk_pessoa_codigo JOIN (SELECT pl.codigo, pl.nome FROM plano pl) AS pl ON ap.fk_plano_codigo = pl.codigo ORDER BY p.nome, f.localizacao;", conexao)
frequencia_aluno
# Out:
# <ipython-input-77-293e8468666b>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   frequencia_aluno = pd.read_sql_query ("SELECT p.nome AS aluno_nome, f.localizacao AS franquia_localizacao, pl.nome AS plano_nome, af.data_hora_inicio, af.data_hora_fim FROM aluno a JOIN pessoa p ON a.fk_pessoa_codigo = p.codigo JOIN aluno_franquia af ON a.fk_pessoa_codigo = af.fk_aluno_fk_pessoa_codigo JOIN franquia f ON af.fk_franquia_codigo = f.codigo JOIN aluno_plano ap ON a.fk_pessoa_codigo = ap.fk_aluno_fk_pessoa_codigo JOIN (SELECT pl.codigo, pl.nome FROM plano pl) AS pl ON ap.fk_plano_codigo = pl.codigo ORDER BY p.nome, f.localizacao;", conexao)
#           aluno_nome                   franquia_localizacao plano_nome  \
# 0    Alice Rodrigues             Centro, Rua Principal, 123     bronze
# ...

# %%
horas_trabalho_prof = pd.read_sql_query ("SELECT professor_nome, franquia_localizacao, total_horas_trabalhadas FROM (SELECT p.nome AS professor_nome, f.localizacao AS franquia_localizacao, SUM(EXTRACT(EPOCH FROM (pf.data_hora_fim - pf.data_hora_inicio)) / 3600) AS total_horas_trabalhadas FROM professor pr JOIN pessoa p ON pr.fk_pessoa_codigo = p.codigo JOIN professor_franquia pf ON pr.fk_pessoa_codigo = pf.fk_professor_fk_pessoa_codigo JOIN franquia f ON pf.fk_franquia_codigo = f.codigo GROUP BY p.nome, f.localizacao) AS subquery ORDER BY professor_nome, franquia_localizacao;;", conexao)
horas_trabalho_prof
# Out:
# <ipython-input-78-22b2c69b7016>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   horas_trabalho_prof = pd.read_sql_query ("SELECT professor_nome, franquia_localizacao, total_horas_trabalhadas FROM (SELECT p.nome AS professor_nome, f.localizacao AS franquia_localizacao, SUM(EXTRACT(EPOCH FROM (pf.data_hora_fim - pf.data_hora_inicio)) / 3600) AS total_horas_trabalhadas FROM professor pr JOIN pessoa p ON pr.fk_pessoa_codigo = p.codigo JOIN professor_franquia pf ON pr.fk_pessoa_codigo = pf.fk_professor_fk_pessoa_codigo JOIN franquia f ON pf.fk_franquia_codigo = f.codigo GROUP BY p.nome, f.localizacao) AS subquery ORDER BY professor_nome, franquia_localizacao;;", conexao)
#         professor_nome                      franquia_localizacao  \
# 0         Ana Oliveira         Jardim Camburi,  Praça Verde, 456
# ...

# %% [markdown]
# 10 RELATÓRIOS E GRÁFICOS
#
# a) análises e resultados provenientes do banco de dados desenvolvido (usar modelo disponível)

# %% [markdown]
# Relatório de Alunos por Plano: Detalhando o nome, CPF, peso, data de nascimento, altura e o plano assinado por cada aluno.

# %%
alunos_por_plano = pd.read_sql_query ("SELECT  p.nome AS aluno_nome,   p.cpf AS aluno_cpf,  a.peso AS aluno_peso,   p.data_nascimento AS aluno_data_nascimento,    a.altura AS aluno_altura, pl.nome AS plano_nome FROM  pessoa p   INNER JOIN aluno a ON p.codigo = a.fk_pessoa_codigo INNER JOIN aluno_plano ap ON a.fk_pessoa_codigo = ap.fk_aluno_fk_pessoa_codigo    INNER JOIN plano pl ON ap.fk_plano_codigo = pl.codigo ORDER BY    p.nome",conexao)
alunos_por_plano
# Out:
# <ipython-input-79-085db8a38108>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   alunos_por_plano = pd.read_sql_query ("SELECT  p.nome AS aluno_nome,   p.cpf AS aluno_cpf,  a.peso AS aluno_peso,   p.data_nascimento AS aluno_data_nascimento,    a.altura AS aluno_altura, pl.nome AS plano_nome FROM  pessoa p   INNER JOIN aluno a ON p.codigo = a.fk_pessoa_codigo INNER JOIN aluno_plano ap ON a.fk_pessoa_codigo = ap.fk_aluno_fk_pessoa_codigo    INNER JOIN plano pl ON ap.fk_plano_codigo = pl.codigo ORDER BY    p.nome",conexao)
#          aluno_nome       aluno_cpf  aluno_peso aluno_data_nascimento  \
# 0   Adriano Ribeiro  440.500.600-52        75.0            1995-04-30
# 1      Alan Ribeiro  700.100.200-78        72.0            1991-06-10
# 2   Alice Rodrigues  100.200.300-01        70.0            1990-01-15
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns


alunos_por_plano_count = alunos_por_plano.groupby('plano_nome').size()


plt.figure(figsize=(10, 6))
ax = alunos_por_plano_count.plot(kind='barh', color=sns.color_palette('Dark2'))


plt.xlabel('Quantidade de Alunos')
plt.ylabel('Plano')
plt.title('Quantidade de Alunos por Plano')


for container in ax.containers:
    ax.bar_label(container, fmt='%d', padding=3)


plt.gca().spines[['top', 'right']].set_visible(False)


plt.tight_layout()


plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


aluno_plano['data'] = pd.to_datetime(aluno_plano['data'])


aluno_plano['mes'] = aluno_plano['data'].dt.to_period('M').astype(str)


df_count = aluno_plano.groupby(['mes', 'fk_plano_codigo']).size().reset_index(name='count')


plano_mapping = {
    1: 'Bronze',
    2: 'Silver',
    3: 'Gold',
    4: 'Platinum'
}


df_count['plano_nome'] = df_count['fk_plano_codigo'].map(plano_mapping)


cores_planos = {
    'Bronze': 'brown',
    'Silver': 'gray',
    'Gold': '#FFD700',
    'Platinum': '#4A90E2'
}


plt.figure(figsize=(12, 8))
sns.lineplot(data=df_count, x='mes', y='count', hue='plano_nome', palette=cores_planos, marker='o', linewidth=2)


sns.scatterplot(data=df_count, x='mes', y='count', hue='plano_nome', size='count', sizes=(50, 300), palette=cores_planos, legend=None, marker='o')


plt.title('Número de Compras por Plano ao Longo do Tempo em 2024')
plt.xlabel('Mês')
plt.ylabel('Número de Compras')
plt.xticks(rotation=45)
plt.gca().spines[['top', 'right']].set_visible(False)
plt.legend(title='Plano', bbox_to_anchor=(1.05, 1), loc='upper left')


plt.tight_layout()
plt.show()

# %% [markdown]
# Relatório de Professores por Especialidade: Listando o nome, CPF, data de nascimento e especialidade de cada professor, incluindo as franquias em que trabalham.

# %%
professores_especialidade = pd.read_sql_query ("SELECT  p.nome AS professor_nome, p.cpf AS professor_cpf, p.data_nascimento AS professor_data_nascimento,  prof.especialidade AS professor_especialidade,   f.localizacao AS franquia_localizacao FROM  pessoa p   INNER JOIN professor prof ON p.codigo = prof.fk_pessoa_codigo   INNER JOIN professor_franquia pf ON prof.fk_pessoa_codigo = pf.fk_professor_fk_pessoa_codigo INNER JOIN franquia f ON pf.fk_franquia_codigo = f.codigo ORDER BY  p.nome", conexao)
professores_unicos = professores_especialidade.drop_duplicates()
professores_unicos
# Out:
# <ipython-input-83-03465d3ff25e>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   professores_especialidade = pd.read_sql_query ("SELECT  p.nome AS professor_nome, p.cpf AS professor_cpf, p.data_nascimento AS professor_data_nascimento,  prof.especialidade AS professor_especialidade,   f.localizacao AS franquia_localizacao FROM  pessoa p   INNER JOIN professor prof ON p.codigo = prof.fk_pessoa_codigo   INNER JOIN professor_franquia pf ON prof.fk_pessoa_codigo = pf.fk_professor_fk_pessoa_codigo INNER JOIN franquia f ON pf.fk_franquia_codigo = f.codigo ORDER BY  p.nome", conexao)
#         professor_nome   professor_cpf professor_data_nascimento  \
# 0         Ana Oliveira  321.654.987-00                1977-11-25
# 1         Ana Oliveira  321.654.987-00                1977-11-25
# ...

# %%
especialidade_count = (
    professores_especialidade
    .drop_duplicates(subset='professor_cpf')
    .groupby('professor_especialidade')
    .size()
)


plt.figure(figsize=(10, 6))
ax = especialidade_count.plot(kind='bar', color=sns.color_palette('Dark2'))


plt.xlabel('Especialidade')
plt.ylabel('Quantidade de Professores')
plt.title('Quantidade de Professores por Especialidade')


for container in ax.containers:
    ax.bar_label(container, fmt='%d', padding=3)


plt.gca().spines[['top', 'right']].set_visible(False)


plt.tight_layout()


plt.show()

# %% [markdown]
# Relatório de Utilização das Academias: Informando a localização das academias, horários de abertura e fechamento, quantidade de alunos e as franquias associadas

# %%
utilizacao_academias = pd.read_sql_query ("SELECT f.localizacao AS franquia_localizacao, f.hora_abertura AS franquia_hora_abertura, f.hora_fechamento AS franquia_hora_fechamento, COUNT(DISTINCT af.fk_aluno_fk_pessoa_codigo) AS quantidade_alunos FROM franquia f  LEFT JOIN aluno_franquia af ON f.codigo = af.fk_franquia_codigo GROUP BY f.localizacao, f.hora_abertura, f.hora_fechamento ORDER BY f.localizacao;",conexao)
utilizacao_academias
# Out:
# <ipython-input-94-729e59ae62eb>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   utilizacao_academias = pd.read_sql_query ("SELECT f.localizacao AS franquia_localizacao, f.hora_abertura AS franquia_hora_abertura, f.hora_fechamento AS franquia_hora_fechamento, COUNT(DISTINCT af.fk_aluno_fk_pessoa_codigo) AS quantidade_alunos FROM franquia f  LEFT JOIN aluno_franquia af ON f.codigo = af.fk_franquia_codigo GROUP BY f.localizacao, f.hora_abertura, f.hora_fechamento ORDER BY f.localizacao;",conexao)
#                         franquia_localizacao franquia_hora_abertura  \
# 0         Campo Grande, Avenida Central, 456               06:30:00
# 1           Cariacica, Jardim das Rosas, 520               08:00:00
# 2                 Centro, Rua Principal, 123               06:00:00
# ...

# %%
contagem_alunos_por_franquia = (
    aluno_franquia
    .drop_duplicates(subset=['fk_franquia_codigo', 'fk_aluno_fk_pessoa_codigo'])
    .groupby('fk_franquia_codigo')
    .size()
    .reset_index(name='quantidade_alunos')
)


franquias_nomes = pd.read_sql_query(
    """
    SELECT codigo, localizacao
    FROM franquia
    """, conexao
)


contagem_alunos_por_franquia_com_nomes = contagem_alunos_por_franquia.merge(
    franquias_nomes,
    left_on='fk_franquia_codigo',
    right_on='codigo',
    how='left'
).drop(columns=['codigo'])


plt.figure(figsize=(12, 8))
sns.barplot(data=contagem_alunos_por_franquia_com_nomes, x='localizacao', y='quantidade_alunos', palette='viridis')


for index, row in contagem_alunos_por_franquia_com_nomes.iterrows():
    plt.text(row.name, row.quantidade_alunos + 0.5, row.quantidade_alunos, ha='center')

plt.title('Quantidade de Alunos por Franquia')
plt.xlabel('Franquia')
plt.ylabel('Quantidade de Alunos')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-88-088a1fdbe8e9>:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   franquias_nomes = pd.read_sql_query(
# <ipython-input-88-088a1fdbe8e9>:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=contagem_alunos_por_franquia_com_nomes, x='localizacao', y='quantidade_alunos', palette='viridis')

# %%
aluno_franquia['hora_inicio'] = aluno_franquia['data_hora_inicio'].dt.hour
aluno_franquia['hora_fim'] = aluno_franquia['data_hora_fim'].dt.hour


horas = []
for _, row in aluno_franquia.iterrows():
    for hora in range(row['hora_inicio'], row['hora_fim'] + 1):
        horas.append({'fk_franquia_codigo': row['fk_franquia_codigo'], 'hora': hora})


horas_df = pd.DataFrame(horas)


contagem_horas = horas_df.groupby(['fk_franquia_codigo', 'hora']).size().reset_index(name='quantidade_alunos')


franquias_nomes = pd.read_sql_query(
    """
    SELECT codigo, localizacao
    FROM franquia
    """, conexao
)


contagem_horas_com_nomes = contagem_horas.merge(
    franquias_nomes,
    left_on='fk_franquia_codigo',
    right_on='codigo',
    how='left'
).drop(columns=['codigo'])


plt.figure(figsize=(12, 8))
sns.lineplot(data=contagem_horas_com_nomes, x='hora', y='quantidade_alunos', hue='localizacao', marker='o')


for _, row in contagem_horas_com_nomes.iterrows():
    plt.text(row['hora'], row['quantidade_alunos'] + 0.5, row['quantidade_alunos'], ha='center')

plt.title('Quantidade de Alunos por Hora em Cada Franquia')
plt.xlabel('Hora do Dia')
plt.ylabel('Quantidade de Alunos')
plt.xticks(range(0, 24))
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-92-ade6e1f50640>:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   franquias_nomes = pd.read_sql_query(

# %% [markdown]
# Relatório Financeiro dos Planos: Incluindo nome, valor por aluno e período de cada plano
#
# ---
#
#
#
# ---

# %%
financeiro_planos = pd.read_sql_query ("SELECT  pl.nome AS plano_nome, pl.periodo AS plano_periodo, ap.valor AS valor_por_aluno,  COUNT(ap.codigo) AS numero_alunos, COALESCE(SUM(ap.valor), 0) AS receita_gerada FROM plano pl LEFT JOIN aluno_plano ap ON pl.codigo = ap.fk_plano_codigo GROUP BY pl.nome, pl.periodo, ap.valor ORDER BY  pl.nome", conexao)
financeiro_planos
# Out:
# <ipython-input-178-a91cf960bafb>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   financeiro_planos = pd.read_sql_query ("SELECT  pl.nome AS plano_nome, pl.periodo AS plano_periodo, ap.valor AS valor_por_aluno,  COUNT(ap.codigo) AS numero_alunos, COALESCE(SUM(ap.valor), 0) AS receita_gerada FROM plano pl LEFT JOIN aluno_plano ap ON pl.codigo = ap.fk_plano_codigo GROUP BY pl.nome, pl.periodo, ap.valor ORDER BY  pl.nome", conexao)
#   plano_nome plano_periodo  valor_por_aluno  numero_alunos  receita_gerada
# 0     bronze        mensal             80.0             26          2080.0
# 1       gold     semestral            500.0             24         12000.0
# 2   platinum         anual            900.0             25         22500.0
# 3     silver    trimestral            300.0             25          7500.0

# %%
receita_total = financeiro_planos['receita_gerada'].sum()


financeiro_planos['porcentagem_receita'] = (financeiro_planos['receita_gerada'] / receita_total) * 100


financeiro_planos['rotulo'] = financeiro_planos.apply(
    lambda row: f"{row['plano_nome']} ({row['plano_periodo']}): {row['porcentagem_receita']:.2f}%", axis=1
)


plt.figure(figsize=(10, 8))
plt.pie(
    financeiro_planos['receita_gerada'],
    labels=financeiro_planos['rotulo'],
    autopct='%1.1f%%',
    startangle=140,
    colors=sns.color_palette("pastel")
)
plt.title('Porcentagem de Receita Gerada por Plano e Período')
plt.axis('equal')
plt.show()

# %% [markdown]
# Relatório de Atividades: Detalhando o nome da atividade, o professor responsável e as franquias onde são oferecidas.

# %%
atividades_franquias = pd.read_sql_query (" SELECT a.nome AS atividade_nome, p.nome AS professor_nome,  f.localizacao AS franquia_localizacao FROM atividade a INNER JOIN professor_atividade pa ON a.codigo = pa.fk_atividade_codigo INNER JOIN professor pr ON pa.fk_professor_fk_pessoa_codigo = pr.fk_pessoa_codigo  INNER JOIN pessoa p ON pr.fk_pessoa_codigo = p.codigo INNER JOIN atividade_franquia af ON a.codigo = af.fk_atividade_codigo  INNER JOIN franquia f ON af.fk_franquia_codigo = f.codigo ORDER BY  a.nome, p.nome, f.localizacao", conexao)
atividades_franquias
# Out:
# <ipython-input-180-95205f401e86>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   atividades_franquias = pd.read_sql_query (" SELECT a.nome AS atividade_nome, p.nome AS professor_nome,  f.localizacao AS franquia_localizacao FROM atividade a INNER JOIN professor_atividade pa ON a.codigo = pa.fk_atividade_codigo INNER JOIN professor pr ON pa.fk_professor_fk_pessoa_codigo = pr.fk_pessoa_codigo  INNER JOIN pessoa p ON pr.fk_pessoa_codigo = p.codigo INNER JOIN atividade_franquia af ON a.codigo = af.fk_atividade_codigo  INNER JOIN franquia f ON af.fk_franquia_codigo = f.codigo ORDER BY  a.nome, p.nome, f.localizacao", conexao)
#            atividade_nome professor_nome  \
# 0    Acompanhamento dieta  Fernando Lima
# 1    Acompanhamento dieta  Fernando Lima
# 2    Acompanhamento dieta  Fernando Lima
# ...

# %%
atividades_franquias_count = atividades_franquias.groupby(['franquia_localizacao', 'atividade_nome']).size().unstack().fillna(0)


plt.figure(figsize=(18, 10))
atividades_franquias_count.plot(kind='bar', stacked=True, colormap='tab20', edgecolor='black', figsize=(14, 8))


plt.legend(title='Atividades', bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small', title_fontsize='medium')


plt.title('Atividades Fornecidas em Cada Franquia')
plt.xlabel('Localização da Franquia')
plt.ylabel('Contagem de Atividades')
plt.xticks(rotation=45, ha='right')


plt.tight_layout()


plt.show()

# %% [markdown]
# #11 AJUSTES DA DOCUMENTAÇÃO, CRIAÇÃO DOS SLIDES E VÍDEO PARA APRESENTAÇAO FINAL
# a) Modelo (pecha kucha)<br>
# b) Tempo de apresentação 6:40<br>
#
# https://drive.google.com/drive/folders/1oCXuyUrGxI61uSfeuIWGvI4d0nzYMkti

# %%
from IPython.display import HTML

video_id = 'ROGjAI4SUTE'

HTML(f"""
<iframe width="800" height="600" src="https://www.youtube.com/embed/{video_id}" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
""")
# Out:
# <iframe width="800" height="600" src="https://www.youtube.com/embed/ROGjAI4SUTE" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# #12 FORMATACAO NO GIT:
#
# ##https://github.com/bmazega/TemplateBD1
